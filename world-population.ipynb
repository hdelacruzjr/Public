# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df= pd.read_csv('/kaggle/input/countries-in-the-world-by-population-2022/world_population.csv')

# %%
df

# %%
sns.histplot(df['Med. Age'],kde= True)

# %%
sns.histplot(df['Fert. Rate'],kde= True)

# %%
df_corr= df.corr(numeric_only= True)

# %%
df_corr

# %%
sns.heatmap(df_corr, annot= True)
